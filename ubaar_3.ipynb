# %% [markdown]
# # Advanced regression
#
# In this section i will perform hyperparameters optimisation on **RandomForest**, **LightGBM** and **MLPRegressor** estimators. Then by Three estimators obtained from hyperparameter optimisation procedure, I will develop a simple custom regressor that uses these algorithms and performs a simple averaging strategy for making a more robust and accurate estimator.
#
# So let's begin.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.model_selection import train_test_split

# %%
# Define a function for splitting Data to train and test sets, in a stratified manner
def split_data(X, y):
    bins = np.linspace(0, len(y), 100)
    y_binned = np.digitize(y, bins)
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y_binned)
    return x_train, x_test, y_train, y_test

# load previously saved data
data = pd.read_csv('ubaar_data.csv', index_col='ID')
X, y = data.drop('logPrice', axis=1), data['logPrice']
x_train, x_test, y_train, y_test = split_data(X, y)

# Define a function for evaluating the regressor using t-times k-fold cross validation,
# note that this function does not use stratified folding.
from sklearn.model_selection import cross_val_score

def t_times_k_fold_cv(model, X, y, t=5, k=3):
    def score_func(y, y_pred):
        y_true = np.exp(y)
        y_pred = np.exp(y_pred)
        return 100 - np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    scorer = make_scorer(score_func=score_func)
    scores = []
    for i in range(t):
        scores.extend(cross_val_score(model, X, y, cv=k, scoring=scorer).tolist())
    return np.array(scores)

def maps(y, y_pred):
        y_true = np.exp(y)
        y_pred = np.exp(y_pred)
        return 100 - np.mean(np.abs((y_true - y_pred) / y_true)) * 100

scorer = make_scorer(maps)

# %% [markdown]
# # Hyperparameter optimization
#
# RandomForest, LightGBM and MLP algorithms take many parameters that should set by data scientist before training the model, such as number of trees in RandomForest. Controlling the hyperparameters affects the model performance by altering the balance between underfitting and overfitting in a model.
#
# The problem with choosing the right hyperparameters is that the optimal set will be different for every machine learning problem! Therefore, the only way to find the best settings is to try out a number of them on each new dataset. We will use **RandomSearch with Cross-Validation** for hyperparameter optimization.
#
# ## Random Search with Cross-Validation
#
# We define a grid of hyperparameters, and create a model with a combination of hyperparameters randomly sampled from grid. Then we will evaluate the trained model using K-fold Cross-validation, and selecting the best hyperparameters.
#
#
# ### Hyperparameter optimization for RandomForestRegressor
#
# Let's fine-tune the RandomForestRegressor :

# %%
# Implementing a randomsearch for finding optimal parameters in RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import make_scorer

n_estimators = [50, 200, 500, 1000]
max_features = [0.1, 0.5, 0.9]
max_depth = [None, 5, 20, 50]
min_samples_split = [2, 30, 100]
min_samples_leaf = [1, 5, 20]
max_leaf_nodes = [None, 5, 20]
min_impurity_decrease = [0, 0.1, 0.5]

hyperparameter_grid = {'n_estimators': n_estimators,
                       'max_features': max_features,
                       'max_depth': max_depth,
                       'min_samples_split': min_samples_split,
                       'min_samples_leaf': min_samples_leaf,
                       'max_leaf_nodes': max_leaf_nodes,
                       'min_impurity_decrease': min_impurity_decrease}
model = RandomForestRegressor(random_state=42, n_jobs=6)
random_cv = RandomizedSearchCV(estimator=model,
                               param_distributions=hyperparameter_grid,
                               cv=4,
                               n_iter=50, 
                               scoring=scorer,
                               n_jobs=1,
                               verbose=1 
                               return_train_score=True,
                               random_state=42)
random_cv.fit(x_train, y_train)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   0.6s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   0.4s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   0.4s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   0.4s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   1.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   1.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   1.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   1.6s
# [CV] n_estimators=200, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=20
# [CV]  n_estimators=200, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=20, total=   0.9s
# [CV] n_estimators=200, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=20
# [CV]  n_estimators=200, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=20, total=   0.8s
# [CV] n_estimators=200, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=20
# [CV]  n_estimators=200, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=20, total=   0.8s
# [CV] n_estimators=200, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=20
# [CV]  n_estimators=200, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=20, total=   0.8s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=20, total=   3.7s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=20, total=   3.3s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=20, total=   3.9s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=20, total=   3.3s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.1, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.1, max_depth=None, total=   1.6s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.1, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.1, max_depth=None, total=   1.7s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.1, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.1, max_depth=None, total=   1.6s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.1, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.1, max_depth=None, total=   1.6s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.9, max_depth=50
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.9, max_depth=50, total=   0.4s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.9, max_depth=50
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.9, max_depth=50, total=   0.3s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.9, max_depth=50
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.9, max_depth=50, total=   0.3s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.9, max_depth=50
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.9, max_depth=50, total=   0.4s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=None, total=  19.3s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=None, total=  19.4s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=None, total=  18.0s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=None, total=  17.7s
# [CV] n_estimators=200, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None
# [CV]  n_estimators=200, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None, total=   0.5s
# [CV] n_estimators=200, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None
# [CV]  n_estimators=200, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None, total=   0.5s
# [CV] n_estimators=200, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None
# [CV]  n_estimators=200, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None, total=   0.5s
# [CV] n_estimators=200, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None
# [CV]  n_estimators=200, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None, total=   0.5s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   1.2s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   1.2s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   1.2s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   1.2s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.5, max_depth=None
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.5, max_depth=None, total=   1.1s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.5, max_depth=None
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.5, max_depth=None, total=   1.1s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.5, max_depth=None
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.5, max_depth=None, total=   1.1s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.5, max_depth=None
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.5, max_depth=None, total=   1.1s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=  13.5s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=  13.3s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=  13.3s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=  13.4s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=5, total=   2.0s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=5, total=   2.0s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=5, total=   2.0s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=5, total=   2.0s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.9, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.9, max_depth=5, total=  12.3s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.9, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.9, max_depth=5, total=  12.4s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.9, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.9, max_depth=5, total=  13.2s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.9, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.9, max_depth=5, total=  12.9s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None, total=   0.6s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None, total=   0.6s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None, total=   0.7s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None, total=   0.6s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None, total=   1.6s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None, total=   1.8s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None, total=   1.9s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.1, max_depth=None, total=   1.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None, total=   4.1s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None, total=   3.9s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None, total=   4.2s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None, total=   3.7s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5, total=   0.6s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5, total=   0.6s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5, total=   0.6s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5, total=   0.5s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   2.1s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   2.0s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   2.0s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   2.2s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20, total=   4.9s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20, total=   4.6s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20, total=   4.6s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20, total=   4.5s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=5
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=5, total=   1.6s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=5
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=5, total=   1.6s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=5
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=5, total=   1.6s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=5
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=5, total=   1.6s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=5, total=   2.4s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=5, total=   2.5s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=5, total=   2.4s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=5, total=   2.4s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.5, max_depth=None
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.5, max_depth=None, total=   1.2s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.5, max_depth=None
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.5, max_depth=None, total=   1.2s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.5, max_depth=None
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.5, max_depth=None, total=   1.0s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.5, max_depth=None
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=20, max_features=0.5, max_depth=None, total=   1.1s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20, total=   0.4s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20, total=   0.4s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20, total=   0.4s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=20, total=   0.4s
# [CV] n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20
# [CV]  n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20, total=   0.3s
# [CV] n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20
# [CV]  n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20, total=   0.3s
# [CV] n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20
# [CV]  n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20, total=   0.3s
# [CV] n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20
# [CV]  n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20, total=   0.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=20
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=20, total=   0.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=20
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=20, total=   0.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=20
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=20, total=   0.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=20
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=20, total=   0.3s
# [CV] n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None
# [CV]  n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None, total=   0.5s
# [CV] n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None
# [CV]  n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None, total=   0.5s
# [CV] n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None
# [CV]  n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None, total=   0.5s
# [CV] n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None
# [CV]  n_estimators=50, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=None, total=   0.5s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=None, total=   4.7s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=None, total=   4.7s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=None, total=   4.5s
# [CV] n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=None
# [CV]  n_estimators=1000, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.9, max_depth=None, total=   4.6s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=50, total=   0.6s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=50, total=   0.6s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=50, total=   0.6s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=50, total=   0.6s
# [CV] n_estimators=50, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.9, max_depth=None
# [CV]  n_estimators=50, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.9, max_depth=None, total=   0.6s
# [CV] n_estimators=50, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.9, max_depth=None
# [CV]  n_estimators=50, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.9, max_depth=None, total=   0.6s
# [CV] n_estimators=50, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.9, max_depth=None
# [CV]  n_estimators=50, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.9, max_depth=None, total=   0.6s
# [CV] n_estimators=50, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.9, max_depth=None
# [CV]  n_estimators=50, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.9, max_depth=None, total=   0.6s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=None
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=None, total=   1.1s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=None
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=None, total=   1.1s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=None
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=None, total=   1.0s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=None
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=None, total=   1.1s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   1.2s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   1.2s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   1.1s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0.5, max_leaf_nodes=None, max_features=0.5, max_depth=20, total=   1.1s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   0.5s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   0.5s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   0.5s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   0.4s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=20, total=   1.3s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=20, total=   1.2s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=20, total=   1.3s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=20, total=   1.1s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=50
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=50, total=   1.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=50
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=50, total=   1.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=50
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=50, total=   1.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=50
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=5, max_features=0.5, max_depth=50, total=   1.6s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=5
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=5, total=   2.5s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=5
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=5, total=   2.4s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=5
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=5, total=   2.6s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=5
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=5, total=   2.5s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   2.4s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   2.3s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   2.4s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   2.4s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20, total=   0.6s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20, total=   0.6s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20, total=   0.5s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20, total=   0.5s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5, total=   0.9s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5, total=   0.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5, total=   0.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5, total=   0.8s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=50, total=   0.8s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=50, total=   0.9s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=50, total=   0.8s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.5, max_depth=50, total=   0.9s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20, total=   1.6s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20, total=   1.4s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20, total=   1.4s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=20, total=   1.5s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20, total=   0.5s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20, total=   0.6s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20, total=   0.6s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, min_impurity_decrease=0.5, max_leaf_nodes=5, max_features=0.5, max_depth=20, total=   0.6s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5, total=   1.0s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5, total=   0.8s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5, total=   0.8s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5, total=   0.9s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None, total=   0.7s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None, total=   0.6s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None, total=   0.6s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.5, max_depth=None, total=   0.6s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5, total=   1.7s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5, total=   1.9s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5, total=   1.7s
# [CV] n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5
# [CV]  n_estimators=1000, min_samples_split=30, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=5, total=   1.6s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.1, max_depth=5
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.1, max_depth=5, total=   0.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.1, max_depth=5
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.1, max_depth=5, total=   0.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.1, max_depth=5
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.1, max_depth=5, total=   0.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.1, max_depth=5
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=20, min_impurity_decrease=0.1, max_leaf_nodes=None, max_features=0.1, max_depth=5, total=   0.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=50
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=50, total=   0.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=50
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=50, total=   0.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=50
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=50, total=   0.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=50
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, min_impurity_decrease=0.1, max_leaf_nodes=20, max_features=0.1, max_depth=50, total=   0.3s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   6.9s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   6.9s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   7.2s
# [CV] n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50
# [CV]  n_estimators=500, min_samples_split=30, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.9, max_depth=50, total=   6.8s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.1, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.1, max_depth=50, total=   0.8s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.1, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.1, max_depth=50, total=   0.8s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.1, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.1, max_depth=50, total=   0.8s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.1, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=20, min_impurity_decrease=0, max_leaf_nodes=20, max_features=0.1, max_depth=50, total=   0.8s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5, total=   0.3s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5, total=   0.3s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5, total=   0.3s
# [CV] n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5
# [CV]  n_estimators=50, min_samples_split=30, min_samples_leaf=1, min_impurity_decrease=0, max_leaf_nodes=5, max_features=0.1, max_depth=5, total=   0.3s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=50, total=   1.6s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=50, total=   1.5s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=50, total=   1.5s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=50
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=5, min_impurity_decrease=0, max_leaf_nodes=None, max_features=0.1, max_depth=50, total=   1.5s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  8.7min finished
# RandomizedSearchCV(cv=4, error_score='raise',
#           estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=6,
#            oob_score=False, random_state=42, verbose=0, warm_start=False),
#           fit_params=None, iid=True, n_iter=50, n_jobs=1,
#           param_distributions={'n_estimators': [50, 200, 500, 1000], 'max_features': [0.1, 0.5, 0.9], 'max_depth': [None, 5, 20, 50], 'min_samples_split': [2, 30, 100], 'min_samples_leaf': [1, 5, 20], 'max_leaf_nodes': [None, 5, 20], 'min_impurity_decrease': [0, 0.1, 0.5]},
#           pre_dispatch='2*n_jobs', random_state=42, refit=True,
#           return_train_score=True, scoring=make_scorer(maps), verbose=2)

# %%
# Get all of the cv results and sort by the test performance
random_results = pd.DataFrame(random_cv.cv_results_).sort_values('mean_test_score', ascending = False)
random_results.head(10)
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 8        1.137851         0.132754        77.412762         79.504476
# 15       3.826383         0.233544        76.020340         77.311690
# 6       18.339679         0.334336        75.820222         76.832475
# 36       0.488123         0.134210        75.692684         77.059321
# 49       1.457882         0.133087        75.118046         75.958506
# 39       1.402197         0.136084        74.596900         75.499618
# 25       0.439426         0.135782        72.875429         73.270343
# 12      12.477301         0.335175        71.657840         71.856248
# 13       0.559337         0.132805        71.051521         71.229702
# 42       0.556485         0.132899        71.047461         71.228053
#
#    param_max_depth param_max_features param_max_leaf_nodes  \
# 8               20                0.5                 None
# 15            None                0.1                 None
# 6             None                0.5                 None
# 36              20                0.1                 None
# 49              50                0.1                 None
# 39              20                0.1                 None
# 25            None                0.1                 None
# 12               5                0.9                 None
# 13            None                0.5                   20
# 42            None                0.5                   20
#
#    param_min_impurity_decrease param_min_samples_leaf param_min_samples_split  \
# 8                            0                      5                      30
# 15                           0                      5                       2
# 6                            0                     20                       2
# 36                           0                      1                      30
# 49                           0                      5                     100
# 39                           0                      5                       2
# 25                           0                     20                     100
# 12                           0                     20                      30
# 13                           0                     20                      30
# 42                           0                      1                      30
#
#          ...        split1_test_score split1_train_score  split2_test_score  \
# 8        ...                77.322374          79.558909          77.884309
# 15       ...                75.842894          77.305787          76.557419
# 6        ...                75.731190          76.831001          76.325401
# 36       ...                75.682697          77.170042          76.146757
# 49       ...                74.988432          76.009110          75.650397
# 39       ...                74.474741          75.555926          75.074759
# 25       ...                72.658115          73.343762          73.324974
# 12       ...                71.569136          71.903252          72.031965
# 13       ...                71.047477          71.277502          71.358092
# 42       ...                71.048508          71.286976          71.348915
#
#     split2_train_score  split3_test_score  split3_train_score  std_fit_time  \
# 8            79.419349          77.060896           79.590190      0.001726
# 15           77.201160          75.686678           77.408844      0.162585
# 6            76.714625          75.507243           76.967242      0.772019
# 36           76.910745          75.327128           77.094434      0.057877
# 49           75.808366          74.740912           76.013647      0.043227
# 39           75.336089          74.339561           75.656051      0.080701
# 25           73.050033          72.796115           73.507620      0.003258
# 12           71.720679          71.364083           71.953500      0.368386
# 13           71.120030          70.752952           71.254083      0.044661
# 42           71.112401          70.743461           71.243330      0.041731
#
#     std_score_time  std_test_score  std_train_score
# 8         0.001212        0.297987         0.071735
# 15        0.000954        0.328608         0.074267
# 6         0.001516        0.304844         0.089849
# 36        0.002727        0.294138         0.094306
# 49        0.000810        0.332817         0.086767
# 39        0.005007        0.282471         0.119169
# 25        0.004642        0.264093         0.172044
# 12        0.002176        0.241968         0.086778
# 13        0.001692        0.213983         0.063860
# 42        0.001639        0.214061         0.068555
#
# [10 rows x 25 columns]

# %% [markdown]
# The best one:

# %%
# Get best estimator object
random_cv.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#            max_features=0.5, max_leaf_nodes=None, min_impurity_decrease=0,
#            min_impurity_split=None, min_samples_leaf=5,
#            min_samples_split=30, min_weight_fraction_leaf=0.0,
#            n_estimators=50, n_jobs=6, oob_score=False, random_state=42,
#            verbose=0, warm_start=False)

# %% [markdown]
# Now I will perform a grid search on a set of parameters:

# %%
# Grid search on RandomForestRegressor
max_depth = [None]
max_features = [0.5, 0.7, 0.9]
min_samples_leaf = [1, 3, 5]
min_samples_split = [2, 5]
n_estimators = [200]
grid = {'max_depth': max_depth,
        'max_features': max_features,
        'min_samples_leaf': min_samples_leaf,
        'min_samples_split': min_samples_split,
        'n_estimators': n_estimators}
model = RandomForestRegressor(random_state=42, n_jobs=6)
grid_cv = GridSearchCV(estimator=model,
                       param_grid=grid,
                       cv=4,
                       scoring=scorer,
                       n_jobs=1,
                       verbose=1,
                       return_train_score=True)
grid_cv.fit(x_train, y_train)

grid_results = pd.DataFrame(grid_cv.cv_results_).sort_values('mean_test_score', ascending = False)
grid_results.head(10)
# Out:
# Fitting 4 folds for each of 18 candidates, totalling 72 fits
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:  8.7min finished
# GridSearchCV(cv=4, error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=6,
#            oob_score=False, random_state=42, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_depth': [None], 'max_features': [0.5, 0.7, 0.9], 'min_samples_leaf': [1, 3, 5], 'min_samples_split': [2, 5], 'n_estimators': [200]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=make_scorer(maps), verbose=1)

# %%
grid_results = pd.DataFrame(grid_cv.cv_results_).sort_values('mean_test_score', ascending = False)
grid_results.head(10)
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0        5.962511         0.233499        79.513676         89.659085
# 6        7.442325         0.233292        79.473091         89.644433
# 1        5.684880         0.233783        79.463705         87.598060
# 7        7.737860         0.237637        79.434433         87.839555
# 12       9.117845         0.234480        79.416449         89.622960
# 13       8.650456         0.234390        79.395334         87.994861
# 8        7.021611         0.240210        78.787363         84.086538
# 9        6.792192         0.185277        78.787363         84.086538
# 3        4.845764         0.133055        78.782149         83.559732
# 2        4.849395         0.132918        78.782149         83.559732
#
#    param_max_depth param_max_features param_min_samples_leaf  \
# 0             None                0.5                      1
# 6             None                0.7                      1
# 1             None                0.5                      1
# 7             None                0.7                      1
# 12            None                0.9                      1
# 13            None                0.9                      1
# 8             None                0.7                      3
# 9             None                0.7                      3
# 3             None                0.5                      3
# 2             None                0.5                      3
#
#    param_min_samples_split param_n_estimators  \
# 0                        2                200
# 6                        2                200
# 1                        5                200
# 7                        5                200
# 12                       2                200
# 13                       5                200
# 8                        2                200
# 9                        5                200
# 3                        5                200
# 2                        2                200
#
#                                                params       ...         \
# 0   {'max_depth': None, 'max_features': 0.5, 'min_...       ...
# 6   {'max_depth': None, 'max_features': 0.7, 'min_...       ...
# 1   {'max_depth': None, 'max_features': 0.5, 'min_...       ...
# 7   {'max_depth': None, 'max_features': 0.7, 'min_...       ...
# 12  {'max_depth': None, 'max_features': 0.9, 'min_...       ...
# 13  {'max_depth': None, 'max_features': 0.9, 'min_...       ...
# 8   {'max_depth': None, 'max_features': 0.7, 'min_...       ...
# 9   {'max_depth': None, 'max_features': 0.7, 'min_...       ...
# 3   {'max_depth': None, 'max_features': 0.5, 'min_...       ...
# 2   {'max_depth': None, 'max_features': 0.5, 'min_...       ...
#
#     split1_test_score  split1_train_score  split2_test_score  \
# 0           79.338984           89.679047          79.776701
# 6           79.311034           89.657644          79.678108
# 1           79.285599           87.631032          79.698003
# 7           79.269199           87.876538          79.684970
# 12          79.257991           89.642713          79.613172
# 13          79.250328           88.035059          79.606550
# 8           78.622677           84.157319          79.153178
# 9           78.622677           84.157319          79.153178
# 3           78.612694           83.627560          79.191344
# 2           78.612694           83.627560          79.191344
#
#     split2_train_score  split3_test_score  split3_train_score  std_fit_time  \
# 0            89.653303          79.314044           89.654550      0.182280
# 6            89.632150          79.298231           89.649158      0.147220
# 1            87.608109          79.298515           87.613436      0.442782
# 7            87.836210          79.255606           87.847463      0.308201
# 12           89.604424          79.248436           89.625390      0.085906
# 13           87.993379          79.259644           87.999735      0.085844
# 8            84.041696          78.546460           84.103872      0.602027
# 9            84.041696          78.546460           84.103872      0.316202
# 3            83.504359          78.524657           83.593352      0.002775
# 2            83.504359          78.524657           83.593352      0.004542
#
#     std_score_time  std_test_score  std_train_score
# 0         0.000821        0.194894         0.011677
# 6         0.000930        0.170487         0.009743
# 1         0.000994        0.177328         0.034767
# 7         0.003564        0.180826         0.028140
# 12        0.002605        0.164975         0.013720
# 13        0.000491        0.149060         0.029757
# 8         0.004214        0.234815         0.047942
# 9         0.049629        0.234815         0.047942
# 3         0.000364        0.256303         0.052250
# 2         0.000578        0.256303         0.052250
#
# [10 rows x 23 columns]

# %% [markdown]
# Let's memorize the best estimator obtained from grid search as **best_rf** and evaluate its performance :

# %%
best_rf = RandomForestRegressor(max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=500, n_jobs=6)
t_times_k_fold_cv(best_rf, X, y, 2, 5)
# Out:
# array([ 79.97379088,  80.31594707,  80.15113928,  80.04235786,
#         80.19813729,  80.01685546,  80.30545582,  80.15136359,
#         80.0684021 ,  80.18318024])

# %% [markdown]
# ### Hyperparameter optimization for LightGBM
#
# Define a grid of hyperparameters for random searching:

# %%
# Implementing a randomsearch for finding optimal hyperparameters in LightGBM regressor
import lightgbm as lgb

num_leaves = [10, 100, 200, 500]
max_depth = [-1, 10, 30]
n_estimators = [100, 500, 1000, 1500]
subsample_for_bin = [20000, 50000, 100000]
min_split_gain = [0, 0.001, 0.1]
min_child_samples = [2, 10, 30, 100]
colsample_bytree = [0.1, 0.3, 0.5, 1]
reg_alpha = [0, 0.01, 1]
reg_lambda = [0, 0.01, 1]
bagging_fraction = [0.3, 0.5, 1]
val_metric = ['mae', 'mape', 'mse']

hyperparameter_grid = {'num_leaves': num_leaves,
                       'max_depth': max_depth,
                       'n_estimators': n_estimators,
                       'subsample_for_bin': subsample_for_bin,
                       'min_split_gain': min_split_gain,
                       'min_child_samples': min_child_samples,
                       'colsample_bytree': colsample_bytree,
                       'reg_alpha': reg_alpha,
                       'reg_lambda': reg_lambda,
                       'bagging_fraction': bagging_fraction,
                       'val_metric': val_metric}
model = lgb.LGBMModel(boosting_type='gbdt', objective='regression', random_state=1, n_jobs=6)
random_cv = RandomizedSearchCV(estimator=model,
                               param_distributions=hyperparameter_grid,
                               cv=4, n_iter=50, 
                               scoring = scorer,
                               n_jobs = 1, verbose = 1, 
                               return_train_score = True,
                               random_state=1)
random_cv.fit(x_train, y_train)

# Get all of the cv results and sort by the test performance
random_results = pd.DataFrame(random_cv.cv_results_).sort_values('mean_test_score', ascending = False)
random_results.head(10)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  5.6min finished
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 26       1.426008         0.202459        79.883928         85.520381
# 30       3.889600         0.397936        79.610667         87.655277
# 47       3.222759         0.587429        79.389978         83.545482
# 27       1.097066         0.121675        79.306559         82.639007
# 29       2.126065         0.388462        79.298866         83.154185
# 43       0.947217         0.122921        79.283309         82.618823
# 41       1.614932         0.321640        79.257574         82.794362
# 6        1.989430         0.363029        79.254701         82.766956
# 28       1.872244         0.360536        79.252754         82.817076
# 35       3.284025         0.629318        79.224143         82.468710
#
#    param_bagging_fraction param_colsample_bytree param_max_depth  \
# 26                    0.5                    0.5              10
# 30                    0.3                    0.5              30
# 47                      1                    0.5              30
# 27                    0.3                    0.5              -1
# 29                    0.5                      1              30
# 43                    0.3                    0.5              30
# 41                    0.5                      1              -1
# 6                     0.3                    0.5              10
# 28                    0.3                    0.5              10
# 35                      1                    0.3              -1
#
#    param_min_child_samples param_min_split_gain param_n_estimators  \
# 26                       2                    0                500
# 30                      10                    0                500
# 47                     100                    0               1000
# 27                      10                0.001               1000
# 29                     100                    0                500
# 43                      10                0.001                500
# 41                     100                    0                500
# 6                       30                    0               1000
# 28                      30                    0               1000
# 35                     100                    0               1500
#
#          ...        split1_test_score split1_train_score split2_test_score  \
# 26       ...                79.723863          85.622972         80.175128
# 30       ...                79.492295          87.717045         79.781353
# 47       ...                79.302595          83.677426         79.605373
# 27       ...                79.275162          82.870056         79.634482
# 29       ...                79.211225          83.229124         79.626810
# 43       ...                79.180766          82.845767         79.659647
# 41       ...                79.160328          82.868162         79.548871
# 6        ...                79.131359          82.829129         79.517022
# 28       ...                79.158931          82.893185         79.517358
# 35       ...                79.125424          82.517810         79.543946
#
#    split2_train_score split3_test_score split3_train_score  std_fit_time  \
# 26          85.491379         79.692076          85.488662      0.044517
# 30          87.655963         79.511104          87.672042      0.029644
# 47          83.513488         79.270237          83.449253      0.094454
# 27          82.468570         78.957882          82.571846      0.050279
# 29          83.075801         79.132236          83.222477      0.102307
# 43          82.460799         79.005844          82.615667      0.026494
# 41          82.756873         79.072382          82.811701      0.012934
# 6           82.672065         79.087255          82.819253      0.092750
# 28          82.754424         79.097888          82.828162      0.050350
# 35          82.413409         79.079589          82.479825      0.001982
#
#     std_score_time  std_test_score  std_train_score
# 26        0.006107        0.194234         0.059425
# 30        0.048311        0.117568         0.050923
# 47        0.002731        0.130800         0.083227
# 27        0.002443        0.241251         0.147467
# 29        0.062421        0.192624         0.071814
# 43        0.007376        0.239342         0.142135
# 41        0.005158        0.179361         0.050077
# 6         0.038180        0.167982         0.063222
# 28        0.051656        0.160508         0.051096
# 35        0.011217        0.186258         0.037473
#
# [10 rows x 29 columns]

# %%
pd.set_option('display.max_columns', 50)
random_results.head(10)
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 26       1.426008         0.202459        79.883928         85.520381
# 30       3.889600         0.397936        79.610667         87.655277
# 47       3.222759         0.587429        79.389978         83.545482
# 27       1.097066         0.121675        79.306559         82.639007
# 29       2.126065         0.388462        79.298866         83.154185
# 43       0.947217         0.122921        79.283309         82.618823
# 41       1.614932         0.321640        79.257574         82.794362
# 6        1.989430         0.363029        79.254701         82.766956
# 28       1.872244         0.360536        79.252754         82.817076
# 35       3.284025         0.629318        79.224143         82.468710
#
#    param_bagging_fraction param_colsample_bytree param_max_depth  \
# 26                    0.5                    0.5              10
# 30                    0.3                    0.5              30
# 47                      1                    0.5              30
# 27                    0.3                    0.5              -1
# 29                    0.5                      1              30
# 43                    0.3                    0.5              30
# 41                    0.5                      1              -1
# 6                     0.3                    0.5              10
# 28                    0.3                    0.5              10
# 35                      1                    0.3              -1
#
#    param_min_child_samples param_min_split_gain param_n_estimators  \
# 26                       2                    0                500
# 30                      10                    0                500
# 47                     100                    0               1000
# 27                      10                0.001               1000
# 29                     100                    0                500
# 43                      10                0.001                500
# 41                     100                    0                500
# 6                       30                    0               1000
# 28                      30                    0               1000
# 35                     100                    0               1500
#
#    param_num_leaves param_reg_alpha param_reg_lambda param_subsample_for_bin  \
# 26              200            0.01                1                   50000
# 30              500               0                1                  100000
# 47              200               0             0.01                   20000
# 27              200            0.01                0                   20000
# 29              500            0.01                1                   50000
# 43              200               0                0                   50000
# 41              100            0.01                1                  100000
# 6               500            0.01                1                  100000
# 28              500            0.01                0                  100000
# 35              200            0.01                1                  100000
#
#    param_val_metric                                             params  \
# 26              mae  {'val_metric': 'mae', 'subsample_for_bin': 500...
# 30             mape  {'val_metric': 'mape', 'subsample_for_bin': 10...
# 47             mape  {'val_metric': 'mape', 'subsample_for_bin': 20...
# 27              mse  {'val_metric': 'mse', 'subsample_for_bin': 200...
# 29              mse  {'val_metric': 'mse', 'subsample_for_bin': 500...
# 43              mse  {'val_metric': 'mse', 'subsample_for_bin': 500...
# 41              mae  {'val_metric': 'mae', 'subsample_for_bin': 100...
# 6              mape  {'val_metric': 'mape', 'subsample_for_bin': 10...
# 28             mape  {'val_metric': 'mape', 'subsample_for_bin': 10...
# 35              mse  {'val_metric': 'mse', 'subsample_for_bin': 100...
#
#     rank_test_score  split0_test_score  split0_train_score  split1_test_score  \
# 26                1          79.944638           85.478509          79.723863
# 30                2          79.657910           87.576058          79.492295
# 47                3          79.381707           83.541761          79.302595
# 27                4          79.358703           82.645557          79.275162
# 29                5          79.225203           83.089338          79.211225
# 43                6          79.286980           82.553060          79.180766
# 41                7          79.248715           82.740713          79.160328
# 6                 8          79.283167           82.747376          79.131359
# 28                9          79.236842           82.792532          79.158931
# 35               10          79.147621           82.463797          79.125424
#
#     split1_train_score  split2_test_score  split2_train_score  \
# 26           85.622972          80.175128           85.491379
# 30           87.717045          79.781353           87.655963
# 47           83.677426          79.605373           83.513488
# 27           82.870056          79.634482           82.468570
# 29           83.229124          79.626810           83.075801
# 43           82.845767          79.659647           82.460799
# 41           82.868162          79.548871           82.756873
# 6            82.829129          79.517022           82.672065
# 28           82.893185          79.517358           82.754424
# 35           82.517810          79.543946           82.413409
#
#     split3_test_score  split3_train_score  std_fit_time  std_score_time  \
# 26          79.692076           85.488662      0.044517        0.006107
# 30          79.511104           87.672042      0.029644        0.048311
# 47          79.270237           83.449253      0.094454        0.002731
# 27          78.957882           82.571846      0.050279        0.002443
# 29          79.132236           83.222477      0.102307        0.062421
# 43          79.005844           82.615667      0.026494        0.007376
# 41          79.072382           82.811701      0.012934        0.005158
# 6           79.087255           82.819253      0.092750        0.038180
# 28          79.097888           82.828162      0.050350        0.051656
# 35          79.079589           82.479825      0.001982        0.011217
#
#     std_test_score  std_train_score
# 26        0.194234         0.059425
# 30        0.117568         0.050923
# 47        0.130800         0.083227
# 27        0.241251         0.147467
# 29        0.192624         0.071814
# 43        0.239342         0.142135
# 41        0.179361         0.050077
# 6         0.167982         0.063222
# 28        0.160508         0.051096
# 35        0.186258         0.037473

# %%
# Take a look on best random estimator
random_cv.best_estimator_
# Out:
# LGBMModel(bagging_fraction=0.5, boosting_type='gbdt', class_weight=None,
#      colsample_bytree=0.5, learning_rate=0.1, max_depth=10,
#      min_child_samples=2, min_child_weight=0.001, min_split_gain=0,
#      n_estimators=500, n_jobs=6, num_leaves=200, objective='regression',
#      random_state=1, reg_alpha=0.01, reg_lambda=1, silent=True,
#      subsample=1.0, subsample_for_bin=50000, subsample_freq=0,
#      val_metric='mae')

# %% [markdown]
# Implement grid search on a grid of hyperparameters chosen based on previous results:

# %%
# Grid search
import lightgbm as lgb
num_leaves = [200]
max_depth = [10, 30, 50]
n_estimators = [1000]
subsample_for_bin = [50000, 100000]
min_split_gain = [0]
min_child_samples = [2, 10, 50]
colsample_bytree = [0.5]
reg_alpha = [0, 0.01]
reg_lambda = [0.1, 1]
bagging_fraction = [0.3, 0.5, 1]
val_metric = ['mape']

grid = {'num_leaves': num_leaves,
        'max_depth': max_depth,
       'n_estimators': n_estimators,
       'subsample_for_bin': subsample_for_bin,
       'min_split_gain': min_split_gain,
       'min_child_samples': min_child_samples,
       'colsample_bytree': colsample_bytree,
       'reg_alpha': reg_alpha,
       'reg_lambda': reg_lambda,
       'bagging_fraction': bagging_fraction,
       'val_metric': val_metric}
model = lgb.LGBMModel(boosting_type='gbdt', objective='regression', random_state=1, n_jobs=6)
grid_cv = GridSearchCV(estimator=model,
                       param_grid=grid,
                       cv=4,
                       scoring=scorer,
                       n_jobs=1,
                       verbose=1,
                       return_train_score=True)
grid_cv.fit(x_train, y_train)

grid_results = pd.DataFrame(grid_cv.cv_results_).sort_values('mean_test_score', ascending = False)
grid_results.head(10)
# Out:
# Fitting 4 folds for each of 216 candidates, totalling 864 fits
# [Parallel(n_jobs=1)]: Done 864 out of 864 | elapsed: 79.6min finished
#      mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 151       3.400658         0.414143        79.956666         91.375292
# 150       3.409882         0.409655        79.956666         91.375292
# 78        3.438544         0.422869        79.956666         91.375292
# 79        3.430827         0.418382        79.956666         91.375292
# 6         3.307406         0.414642        79.956666         91.375292
# 7         3.275990         0.417634        79.956666         91.375292
# 74        3.591896         0.421124        79.945928         91.713865
# 75        3.668024         0.468882        79.945928         91.713865
# 147       3.451521         0.417384        79.945928         91.713865
# 146       3.469971         0.417385        79.945928         91.713865
#
#     param_bagging_fraction param_colsample_bytree param_max_depth  \
# 151                      1                    0.5              10
# 150                      1                    0.5              10
# 78                     0.5                    0.5              10
# 79                     0.5                    0.5              10
# 6                      0.3                    0.5              10
# 7                      0.3                    0.5              10
# 74                     0.5                    0.5              10
# 75                     0.5                    0.5              10
# 147                      1                    0.5              10
# 146                      1                    0.5              10
#
#     param_min_child_samples param_min_split_gain param_n_estimators  \
# 151                       2                    0               1000
# 150                       2                    0               1000
# 78                        2                    0               1000
# 79                        2                    0               1000
# 6                         2                    0               1000
# 7                         2                    0               1000
# 74                        2                    0               1000
# 75                        2                    0               1000
# 147                       2                    0               1000
# 146                       2                    0               1000
#
#           ...        split1_test_score split1_train_score split2_test_score  \
# 151       ...                79.981425          91.372666         79.773866
# 150       ...                79.981425          91.372666         79.773866
# 78        ...                79.981425          91.372666         79.773866
# 79        ...                79.981425          91.372666         79.773866
# 6         ...                79.981425          91.372666         79.773866
# 7         ...                79.981425          91.372666         79.773866
# 74        ...                80.090771          91.759219         79.699839
# 75        ...                80.090771          91.759219         79.699839
# 147       ...                80.090771          91.759219         79.699839
# 146       ...                80.090771          91.759219         79.699839
#
#     split2_train_score split3_test_score split3_train_score  std_fit_time  \
# 151          91.425801         79.860212          91.434842      0.016025
# 150          91.425801         79.860212          91.434842      0.026659
# 78           91.425801         79.860212          91.434842      0.044113
# 79           91.425801         79.860212          91.434842      0.033325
# 6            91.425801         79.860212          91.434842      0.078221
# 7            91.425801         79.860212          91.434842      0.058506
# 74           91.828647         79.815825          91.658246      0.156580
# 75           91.828647         79.815825          91.658246      0.147417
# 147          91.828647         79.815825          91.658246      0.018783
# 146          91.828647         79.815825          91.658246      0.030556
#
#      std_score_time  std_test_score  std_train_score
# 151        0.005341        0.164385         0.066420
# 150        0.005054        0.164385         0.066420
# 78         0.005134        0.164385         0.066420
# 79         0.001496        0.164385         0.066420
# 6          0.007308        0.164385         0.066420
# 7          0.011467        0.164385         0.066420
# 74         0.006323        0.194922         0.085512
# 75         0.044352        0.194922         0.085512
# 147        0.003034        0.194922         0.085512
# 146        0.006087        0.194922         0.085512
#
# [10 rows x 29 columns]

# %% [markdown]
# And memorize the best one, then evaluate its performance:

# %%
best_lgb = grid_cv.best_estimator_
t_times_k_fold_cv(best_lgb, X, y)
# Out:
# array([ 80.66245659,  80.78797208,  80.70654313,  80.86267896,
#         80.70861318,  80.66245659,  80.78797208,  80.70654313,
#         80.86267896,  80.70861318,  80.66245659,  80.78797208,
#         80.70654313,  80.86267896,  80.70861318,  80.66245659,
#         80.78797208,  80.70654313,  80.86267896,  80.70861318,
#         80.66245659,  80.78797208,  80.70654313,  80.86267896,  80.70861318])

# %% [markdown]
# ### Hyperparameter optimization on MLPRegressor

# %%
# Implementing a randomsearch for finding optimal hyperparameters in MLP regressor
from sklearn.neural_network import MLPRegressor

hidden_layer_sizes = [(10, 10), (10, 100), (100, 10), (100, 100), (10, 10, 10)]
activation = ['logistic', 'tanh', 'relu']
alpha = [0.0001, 0.01]
batch_size = ['auto', 50, 200, 1000]
momentum = [0.9, 0.7, 0.5]

hyperparameter_grid = {'hidden_layer_sizes': hidden_layer_sizes,
                       'activation': activation,
                       'alpha': alpha,
                       'batch_size': batch_size,
                       'momentum': momentum}
model = MLPRegressor(max_iter=1000, random_state=42)
random_cv = RandomizedSearchCV(estimator=model,
                               param_distributions=hyperparameter_grid,
                               cv=4, n_iter=50, 
                               scoring = make_scorer(score_func=lambda y_true, y_pred: 100 - np.mean(np.abs((np.exp(y_true) - np.exp(y_pred)) / np.exp(y_true)) * 100)),
                               n_jobs = 6, verbose = 2, 
                               return_train_score = True,
                               random_state=42)
random_cv.fit(x_train, y_train)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# [Parallel(n_jobs=6)]: Done  29 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done 150 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=6)]: Done 200 out of 200 | elapsed: 12.0min finished
# RandomizedSearchCV(cv=4, error_score='raise',
#           estimator=MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False),
#           fit_params=None, iid=True, n_iter=50, n_jobs=6,
#           param_distributions={'hidden_layer_sizes': [(10, 10), (10, 100), (100, 10), (100, 100), (10, 10, 10)], 'activation': ['logistic', 'tanh', 'relu'], 'alpha': [0.0001, 0.01], 'batch_size': ['auto', 50, 200, 1000], 'momentum': [0.9, 0.7, 0.5]},
#           pre_dispatch='2*n_jobs', random_state=42, refit=True,
#           return_train_score=True, scoring='neg_mean_squared_error',
#           verbose=2)

# %%
# Get all of the cv results and sort by the test performance
random_results = pd.DataFrame(random_cv.cv_results_).sort_values('mean_test_score', ascending = False)
random_results.head(10)
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 6       22.253013         0.058843        -0.080866         -0.078523
# 15      29.707349         0.095745        -0.081200         -0.074536
# 44      39.928854         0.099734        -0.081200         -0.074536
# 36      30.913944         0.085772        -0.081456         -0.078916
# 39      12.256478         0.056350        -0.082085         -0.080294
# 40      10.950720         0.059092        -0.082650         -0.079913
# 12      12.290141         0.065324        -0.082650         -0.079913
# 35      36.611858         0.102975        -0.083455         -0.081756
# 31      29.985923         0.102228        -0.083455         -0.081756
# 28      33.583297         0.102724        -0.083784         -0.081530
#
#    param_activation param_alpha param_batch_size param_hidden_layer_sizes  \
# 6          logistic      0.0001               50                 (10, 10)
# 15             tanh      0.0001             auto                (100, 10)
# 44             tanh      0.0001              200                (100, 10)
# 36         logistic      0.0001               50                (100, 10)
# 39         logistic        0.01              200                 (10, 10)
# 40             tanh        0.01             auto                 (10, 10)
# 12             tanh        0.01              200                 (10, 10)
# 35         logistic      0.0001              200               (100, 100)
# 31         logistic      0.0001             auto               (100, 100)
# 28         logistic      0.0001               50               (100, 100)
#
#    param_momentum                                             params  \
# 6             0.9  {'momentum': 0.9, 'hidden_layer_sizes': (10, 1...
# 15            0.9  {'momentum': 0.9, 'hidden_layer_sizes': (100, ...
# 44            0.7  {'momentum': 0.7, 'hidden_layer_sizes': (100, ...
# 36            0.7  {'momentum': 0.7, 'hidden_layer_sizes': (100, ...
# 39            0.9  {'momentum': 0.9, 'hidden_layer_sizes': (10, 1...
# 40            0.9  {'momentum': 0.9, 'hidden_layer_sizes': (10, 1...
# 12            0.9  {'momentum': 0.9, 'hidden_layer_sizes': (10, 1...
# 35            0.9  {'momentum': 0.9, 'hidden_layer_sizes': (100, ...
# 31            0.9  {'momentum': 0.9, 'hidden_layer_sizes': (100, ...
# 28            0.7  {'momentum': 0.7, 'hidden_layer_sizes': (100, ...
#
#          ...         split1_test_score  split1_train_score  split2_test_score  \
# 6        ...                 -0.081795           -0.078338          -0.081593
# 15       ...                 -0.083488           -0.075977          -0.083231
# 44       ...                 -0.083488           -0.075977          -0.083231
# 36       ...                 -0.082875           -0.079749          -0.082667
# 39       ...                 -0.082555           -0.079740          -0.083600
# 40       ...                 -0.083242           -0.079734          -0.084125
# 12       ...                 -0.083242           -0.079734          -0.084125
# 35       ...                 -0.084268           -0.081261          -0.085418
# 31       ...                 -0.084268           -0.081261          -0.085418
# 28       ...                 -0.083302           -0.080195          -0.083196
#
#     split2_train_score  split3_test_score  split3_train_score  std_fit_time  \
# 6            -0.077881          -0.079422           -0.078513      4.714045
# 15           -0.074075          -0.080976           -0.076739      3.217046
# 44           -0.074075          -0.080976           -0.076739      6.261992
# 36           -0.078846          -0.079282           -0.077512      5.558040
# 39           -0.080250          -0.081316           -0.080819      1.655196
# 40           -0.079554          -0.082248           -0.080737      0.196536
# 12           -0.079554          -0.082248           -0.080737      1.090460
# 35           -0.082238          -0.081490           -0.080955      7.886792
# 31           -0.082238          -0.081490           -0.080955      2.089370
# 28           -0.079782          -0.083851           -0.083077      0.853462
#
#     std_score_time  std_test_score  std_train_score
# 6         0.004172        0.000938         0.000536
# 15        0.000705        0.002558         0.002077
# 44        0.002908        0.002558         0.002077
# 36        0.005231        0.001450         0.000878
# 39        0.002950        0.001071         0.000384
# 40        0.002481        0.001168         0.000480
# 12        0.007243        0.001168         0.000480
# 35        0.003888        0.001503         0.000667
# 31        0.003192        0.001503         0.000667
# 28        0.004622        0.000630         0.001549
#
# [10 rows x 23 columns]

# %%
best_mlp = random_cv.best_estimator_
t_times_k_fold_cv(best_mlp, X, y)
# Out:
# array([ 78.30386441,  77.81224731,  77.4210379 ,  77.09670888,
#         76.52366954,  78.30386441,  77.81224731,  77.4210379 ,
#         77.09670888,  76.52366954,  78.30386441,  77.81224731,
#         77.4210379 ,  77.09670888,  76.52366954,  78.30386441,
#         77.81224731,  77.4210379 ,  77.09670888,  76.52366954,
#         78.30386441,  77.81224731,  77.4210379 ,  77.09670888,  76.52366954])

# %% [markdown]
# ## Averaging regressor
#
# Now I will define an estimator class that gets some estimators as args and averages given estimators' predictions on test data:

# %%
from sklearn.base import BaseEstimator, ClassifierMixin

class AveragingRegressor(BaseEstimator, ClassifierMixin):
    def __init__(self, estimators=list()):
        self.estimators = estimators
        
    def fit(self, X, y=None):
        for estimator in self.estimators:
            estimator.fit(X, y)
        return self
    
    def predict(self, X):
        return np.mean(np.array([estimator.predict(X) for estimator in self.estimators]), axis=0)
    
    def get_params(self, deep=True):
        return {"estimators": self.estimators}
    
    def set_params(self, **parameters):
        for parameter, value in parameters.items():
            setattr(self, parameter, value)
        return self

# %% [markdown]
# Evaluate performance:

# %%
myregressor = AveragingRegressor(estimators=[best_rf, best_lgb, best_mlp])
t_times_k_fold_cv(myregressor, X, y)
# Out:
# array([ 80.72004038,  80.62611435,  80.45712291,  80.31719054,
#         80.2183164 ,  80.72523548,  80.6184246 ,  80.44931862,
#         80.31194192,  80.2182443 ,  80.72142188,  80.63177045,
#         80.45287373,  80.3193459 ,  80.21204319,  80.7169413 ,
#         80.62308526,  80.46470665,  80.33018874,  80.21544911,
#         80.72691201,  80.62911723,  80.45282844,  80.31567721,  80.21755084])
